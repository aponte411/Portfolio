# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "http://d3v3hv0xzfxuou.cloudfront.net/wp-content/uploads/2018/04/10103408/maxresdefault-2.jpg")
# Out:
# <img src="http://d3v3hv0xzfxuou.cloudfront.net/wp-content/uploads/2018/04/10103408/maxresdefault-2.jpg"/>

# %% [markdown]
# ## Introduction:
#
# Jeopardy is a popular TV show in the United States where participants answer random trivia questions to win money. It's been running since the early 60's and has still maintained a large viewership.
#
# ## Objective:
#
# Let's say I want to compete on Jeopardy, so I decide to analyze some questions from their database to see if I can discover any patterns or insights for a competitive advantage. In this project I am going to clean up the dataset, come up with a strategy, and explore the questions to see if there are any relevant insights to help me win the game.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("JEOPARDY_CSV.csv")
df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
# Show Number    216930 non-null int64
#  Air Date      216930 non-null object
#  Round         216930 non-null object
#  Category      216930 non-null object
#  Value         216930 non-null object
#  Question      216930 non-null object
#  Answer        216928 non-null object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
df = df.dropna()

# %% [markdown]
# ## Tidying up the data:
#
# - Since some of the columns names have spaces I'll tidy up the names.
# - The answer, question, and value columns need to be cleaned. Both the answer and question columns have non-numeric characters like "." that need to be removed. I'll create a function to this.
# - The value column isn't in numeric format, so I'll convert that to numeric type.
# - The air_date column needs to be converted to datetime.

# %%
df.columns = ['show_number', 'air_date', 'round', 'category', 'value', 'question', 'answer']

# %%
df.head()
# Out:
#    show_number    air_date      round                         category value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             question      answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
df["answer"].sample(5), df["question"].sample(5)
# Out:
# (71230            shin splints
#  57064         Double entendre
#  172170    Freddie Prinze, Jr.
#  105169       Ulysses S. Grant
#  42834           Vinson Massif
#  Name: answer, dtype: object,
#  72905     The pygmy variety of this small South American...
#  150680    Once home to the Hittites, today this region i...
#  110763    Her final testament, read in public after her ...
#  153370             To poke, perhaps with a cattle implement
#  189599    In 1954 Monaco's Prince Rainier created the Or...
#  Name: question, dtype: object)

# %% [markdown]
# Creating a function to clean answer and question columns - this will make it much easier to analyze later.

# %%
import re
def cleaner(string):
    lower = string.lower()
    clean = re.sub("[^A-za-z0-9\s]", "", lower)
    return clean

# %%
# check function
cleaner("No way. That's impossible.")
# Out:
# 'no way thats impossible'

# %%
df["clean_answer"] = df["answer"].apply(cleaner)
df["clean_answer"].head()
# Out:
# 0    copernicus
# 1    jim thorpe
# 2       arizona
# 3     mcdonalds
# 4    john adams
# Name: clean_answer, dtype: object

# %%
df["clean_question"] = df["question"].apply(cleaner)
df["clean_question"].head()
# Out:
# 0    for the last 8 years of his life galileo was u...
# 1    no 2 1912 olympian football star at carlisle i...
# 2    the city of yuma in this state has a record av...
# 3    in 1963 live on the art linkletter show this c...
# 4    signer of the dec of indep framer of the const...
# Name: clean_question, dtype: object

# %%
df["value"].head(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216928 entries, 0 to 216929
# Data columns (total 9 columns):
# show_number       216928 non-null int64
# air_date          216928 non-null object
# round             216928 non-null object
# category          216928 non-null object
# value             216928 non-null object
# question          216928 non-null object
# answer            216928 non-null object
# clean_answer      216928 non-null object
# clean_question    216928 non-null object
# dtypes: int64(1), object(8)
# memory usage: 16.6+ MB
# (0    $200
#  1    $200
#  2    $200
#  3    $200
#  4    $200
#  Name: value, dtype: object, None)

# %% [markdown]
# Creating a function to convert value column into integers - this way we can do calculations.

# %%
def cleaner2(string):
    string = re.sub("[^A-za-z0-9\s]", "", string)
    try:
        num = int(string)
    except Exception:
        num = 0
        
    return num

# %%
df["clean_value"] = df["value"].apply(cleaner2)
df["clean_value"].head()
# Out:
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# Name: clean_value, dtype: int64

# %% [markdown]
# Converting air_date into datetime - this will make analyzing time much easier.

# %%
df["air_date"] = pd.to_datetime(df["air_date"])
df["air_date"].head()
# Out:
# 0   2004-12-31
# 1   2004-12-31
# 2   2004-12-31
# 3   2004-12-31
# 4   2004-12-31
# Name: air_date, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216928 entries, 0 to 216929
# Data columns (total 10 columns):
# show_number       216928 non-null int64
# air_date          216928 non-null datetime64[ns]
# round             216928 non-null object
# category          216928 non-null object
# value             216928 non-null object
# question          216928 non-null object
# answer            216928 non-null object
# clean_answer      216928 non-null object
# clean_question    216928 non-null object
# clean_value       216928 non-null int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 18.2+ MB

# %%
df.head()
# Out:
#    show_number   air_date      round                         category value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             question      answer clean_answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus   copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe   jim thorpe
# 2  The city of Yuma in this state has a record av...     Arizona      arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's    mcdonalds
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams   john adams
#
#                                       clean_question  clean_value
# 0  for the last 8 years of his life galileo was u...          200
# 1  no 2 1912 olympian football star at carlisle i...          200
# 2  the city of yuma in this state has a record av...          200
# 3  in 1963 live on the art linkletter show this c...          200
# 4  signer of the dec of indep framer of the const...          200

# %% [markdown]
# ## Strategy:
#
# In order to figure out whether to study past questions, study general knowledge, or not study it all, it would be helpful to figure out two things before choosing a strategy:
#
# - How often the answer is deducible from the question?
# - How often new questions are repeats of older questions?
#
# I can answer the second question by figuring out how often "complex" words (any word over 6 characters) reoccur. I can answer the first question by figuring out how many times some words in the answer also occur in the question. I'll start with the first question then work my way to the second.

# %% [markdown]
# I'll create a function to go through the answers and questions, removing words like "the" (I consider those worse extraneous for this analysis), and finding the proportion of answers that occur in the questions. Afterwards, I'll take the average and convert the result into a percentage.

# %%
def jeopordy(row):
    split_answer = row['clean_answer'].split(" ")
    split_question = row['clean_question'].split(" ")
    match_count = 0
    if "the" in split_answer:
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0
    for i in split_answer:
        if i in split_question:
            match_count += 1
    return match_count/len(split_answer)

# %%
df["answer_in_question"] = df.apply(jeopordy, axis=1)

# %%
df["answer_in_question"].mean()*100
# Out:
# 5.932118970835468

# %% [markdown]
# ## Findings:
#
# Only 6% of the answers are in the question and this isn't a large amount given the sample size - this dataset is only a small sample from Jeoparday's database of questions.

# %% [markdown]
# Now, I'll create a function to filter for the words that have at least 5 letters, and then find the proportion of repeated questions. Afterwards, I'll the find mean and convert it to a percentage. Along the way I'll find the unique terms used using a set().

# %%
question_overlap = []
terms_used = set()
for i, v in df.iterrows():
    split_question = v["clean_question"].split(" ")
    split_question = [i for i in split_question if len(i) > 5]
    match_count = 0
    for i in split_question:
        if i in terms_used:
            match_count += 1
    for i in split_question:
        terms_used.add(i)
    if len(split_question) > 0:
        match_count /= len(split_question)
        
    question_overlap.append(match_count)

# %%
df["question_overlap"] = question_overlap
df["question_overlap"].mean()*100
# Out:
# 87.34641512699052

# %%
terms_used
# Out:
# {'19941996',
#  'jockey',
#  'veraellen',
#  'stitzer',
#  'goldsmith',
#  'wheeling',
#  'stagecoaches',
#  'deceive',
#  'grooving',
#  'dingdong',
#  'gramps',
#  'rostropovich',
#  'mormons',
#  'divebombing',
#  'kaminker',
#  '60foot',
#  'hrefhttpwwwjarchivecommedia20080918_dj_08jpg',
#  'giftsbut',
#  'spelman',
#  'hrefhttpwwwjarchivecommedia20060221_dj_17jpg',
#  'tomorrowland',
#  'hrefhttpwwwjarchivecommedia20120102_j_02ajpg',
#  'coworker',
#  'charmingly',
#  'omniscient',
#  'excitement',
#  'burgos',
#  'handiwork',
#  'instrumentals',
#  'publicize',
#  'yemanja',
#  'defibrillator',
#  'autoclaved',
#  'javelin',
#  'ginastera',
#  'attallah',
#  'hrefhttpwwwjarchivecommedia20080725_j_04jpg',
#  'rijsttafel',
#  'struts',
#  '22211foot',
#  'westerplatte',
#  'overlooking',
#  'officesa',
#  'copperrolling',
#  'longricola',
#  'microprocessor',
#  'hrefhttpwwwjarchivecommedia20070404_j_09jpg',
#  'hrefhttpwwwjarchivecommedia20090316_j_12mp3monsieur',
#  'ananas',
#  'desertdwelling',
#  'rawalpindi',
#  'reginalds',
#  'singlehorned',
#  'writfen',
#  'classifieds',
#  'perfectionists',
#  'piscatology',
#  'divinities',
#  'geordie',
#  'unproven',
#  'glasssteagall',
#  'federal',
#  'abundant',
#  'powerbook',
#  'patternmaking',
#  'bearwrestling',
#  'saffron',
#  'knossos',
#  'ratesa',
#  'partiridium',
#  'dagoult',
#  'scooby',
#  'tiltrotor',
#  'probing',
#  'tailgunner',
#  'matchbox',
#  'petrel',
#  'succeeding',
#  'shonin',
#  'ribier',
#  'nythemed',
#  'agentstobe',
#  'philosophic',
#  'undulate',
#  'schuylkill',
#  'billiard',
#  'inagaddadavida',
#  'vanuatus',
#  '19351978',
#  'signify',
#  'oftenwooden',
#  'schmuck',
#  'fiftieth',
#  'scramble',
#  'mercury',
#  'crooning',
#  'spagna',
#  '220000',
#  '185mile',
#  'varied',
#  'hrefhttpwwwjarchivecommedia20040705_dj_28jpg',
#  'kweisi',
#  'gettin',
#  'massine',
#  'nameplate',
#  'operating',
#  'notions',
#  'mimicking',
#  '19561980',
#  'affair',
#  'grenouille',
#  'ludwigs',
#  'phyllo',
#  'theses',
#  'bwhseb',
#  'scaleless',
#  'homeschools',
#  'calibrated',
#  'stouts',
#  'enactment',
#  'obrian',
#  'kinsky',
#  'feuding',
#  'monicas',
#  'athlete',
#  'souper',
#  'hrefhttpwwwjarchivecommedia20011101_dj_24jpg',
#  'lenders',
#  'ranelid',
#  'browne',
#  'knives',
#  'shivers',
#  'shamal',
#  'faulknerthats',
#  'cymbelline',
#  'oneseason',
#  'volleyed',
#  'ginormica',
#  'weakweakstrong',
#  'tisket',
#  'carrion',
#  'spymobile',
#  'cleopatras',
#  'novocain',
#  'doister',
#  'alphanumerically',
#  'pequot',
#  'rideau',
#  'bourgh',
#  'fearnets',
#  'doorcheck',
#  'hrefhttpwwwjarchivecommedia20080723_dj_03ajpg',
#  'splendor',
#  'canters',
#  'hrefhttpwwwjarchivecommedia19980415_j_13jpg',
#  'oncelost',
#  'hrefhttpwwwjarchivecommedia20080313_dj_24jpg',
#  'hardys',
#  'fleecehe',
#  'impolite',
#  'hrefhttpwwwjarchivecommedia20100310_dj_27jpg',
#  'raskob',
#  'kyotos',
#  'branch',
#  'bertha',
#  'postnatal',
#  'subcontinent',
#  'costarred',
#  'halifax',
#  'longden',
#  'eustis',
#  'sagacious',
#  'stables',
#  'heaveho',
#  'bettys',
#  'gdansk',
#  'sharkey',
#  'sinker',
#  'hatchery',
#  'disappoints',
#  'hrefhttpwwwjarchivecommedia20050408_j_16jpg',
#  'godwinausten',
#  '8002221222',
#  'spongecake',
#  'wholesaler',
#  'strunk',
#  'turnerwilliam',
#  'hrefhttpwwwjarchivecommedia20080404_j_30jpg',
#  'burghley',
#  'calfornia',
#  'cliffdiving',
#  'craigie',
#  'leafnosed',
#  'pollenation',
#  'certain',
#  'mowcher',
#  'deliverers',
#  'benedictine',
#  'donovan',
#  'hrefhttpwwwjarchivecommedia20060529_j_29jpg',
#  'miccosukee',
#  'choreographing',
#  'clunton',
#  'hrefhttpwwwjarchivecommedia20110307_j_24jpg',
#  'uranology',
#  'bartolommeo',
#  'hrefhttpwwwjarchivecommedia20050713_j_08jpg',
#  'americanrussian',
#  'coverers',
#  'moronaba',
#  'beautician',
#  'impenitent',
#  'hendrik',
#  'winfredlouder',
#  'morays',
#  'vengerov',
#  'fortresses',
#  'anabaptist',
#  'fireballs',
#  'flails',
#  'kpauls',
#  'hideho',
#  'scrubs',
#  'hymnals',
#  'mosbius',
#  'longgone',
#  'changeable',
#  'covington',
#  'tuskegees',
#  '338580',
#  'mcconnaughey',
#  'tambora',
#  'goodspeed',
#  'hrefhttpwwwjarchivecommedia20100628_dj_13jpg',
#  'lunchbox',
#  'ogrish',
#  'glenda',
#  'jackets',
#  'hershow',
#  'werden',
#  'warnecke',
#  'fillmores',
#  'commnetator',
#  'bobbing',
#  'dimokratiaa',
#  'fornothing',
#  'unscheduled',
#  'pintado',
#  'liquidfueled',
#  'mellon',
#  'hrefhttpwwwjarchivecommedia20100924_j_29jpg',
#  'rhapsodies',
#  'target_blankadded',
#  'hrefhttpwwwjarchivecommedia20110614_j_12jpg',
#  'chemistry',
#  'condemns',
#  'pandemic',
#  'arragon',
#  'carabelli',
#  'karats',
#  'hrefhttpwwwjarchivecommedia20060323_j_16mp3herea',
#  'remarry',
#  'angies',
#  'lakiha',
#  'hrefhttpwwwjarchivecommedia20050131_j_13mp3thisa',
#  'inexcusable',
#  'aggressor',
#  'marathoners',
#  'maidstone',
#  'yamazaki',
#  'pontificia',
#  'contrition',
#  'krabappel',
#  'target_blankfilm',
#  'transdanubia',
#  'aberration',
#  'hrefhttpwwwjarchivecommedia20040715_j_18jpg',
#  'hrefhttpwwwjarchivecommedia20050531_j_05jpg',
#  'hrefhttpwwwjarchivecommedia20100609_dj_20jpg',
#  'hrefhttpwwwjarchivecommedia20041202_j_09jpg',
#  'capitonyms',
#  'compostela',
#  'foppish',
#  'hrefhttpwwwjarchivecommedia20080723_j_13bjpg',
#  'druids',
#  'quetzalcoatl',
#  'stanza',
#  'lovitz]',
#  'yollotl',
#  'fiveroom',
#  'christens',
#  'irregulars',
#  'cannibalism',
#  'gerund',
#  'ketchikan',
#  'goldwater',
#  'beautified',
#  'laments',
#  '383000',
#  'swarmed',
#  'guadalajara',
#  'wonderly',
#  'winterbourne',
#  'mccall',
#  'segundafeira',
#  'monsoons',
#  'canadianalaskan',
#  'hrefhttpwwwjarchivecommedia20110114_j_16wmvrescuea',
#  'recurs',
#  'batcave',
#  'wakefield',
#  'communicated',
#  'monastery',
#  'lobbied',
#  'passing',
#  'manning',
#  'connectable',
#  'frenchman',
#  '29yearold',
#  'labyrinths',
#  'boullion',
#  'hrefhttpwwwjarchivecommedia20040528_dj_20jpg',
#  'coynes',
#  'protagonists',
#  'goodyears',
#  'lectures',
#  'critiqued',
#  'mockepic',
#  'chartres',
#  'placer',
#  'rumour',
#  'monkeys',
#  'teapot',
#  'gesserit',
#  'spikefilled',
#  'manette',
#  'serene',
#  'armored',
#  'expense',
#  'characters',
#  'crashprone',
#  'hirudinea',
#  'velious',
#  'zirconium',
#  'afraidthis',
#  'eczema',
#  'lapland',
#  'navigation',
#  'hundredweight',
#  'fatimids',
#  'bohemian',
#  'construct',
#  '1813caracasa',
#  'hrefhttpwwwjarchivecommedia20051222_j_02wmv',
#  'attained',
#  'hrefhttpwwwjarchivecommedia20060620_j_12jpg',
#  'broccoflower',
#  'target_blankballoon',
#  'target_blanklibertya',
#  'bitterly',
#  'hrefhttpwwwjarchivecommedia20110316_dj_26jpg',
#  'csonkaa',
#  'princip',
#  'bechtel',
#  'glandswelling',
#  'faceless',
#  'sidesjapanese',
#  'slaughtered',
#  'slaying',
#  'hrefhttpwwwjarchivecommedia20010919_dj_24jpg',
#  'sabrage',
#  'rottnest',
#  'ipequodi',
#  'seagoing',
#  'shandy',
#  'aristocracy',
#  'warwickshire',
#  'tuxens',
#  'keener',
#  'ganster',
#  'rickety',
#  'pergamum',
#  'jacobins',
#  'duvaliers',
#  'wladyslaw',
#  'zoroastrian',
#  'carryall',
#  'cabotin',
#  'emotionally',
#  'dobson',
#  'snacktortilla',
#  'implies',
#  'singerguitarist',
#  'hrefhttpwwwjarchivecommedia20040202_dj_09jpg',
#  'strongbow',
#  'disobedience',
#  'anacostia',
#  'naynays',
#  'mananagement',
#  'interrruptions',
#  'compress',
#  'foilwrapped',
#  'glutes',
#  'puzzlers',
#  'nigricans',
#  'haboob',
#  'shushing',
#  'toobin',
#  'wingsa',
#  'ukuleles',
#  'gaghan',
#  'captivate',
#  'pyramidom',
#  'criminal',
#  'hrefhttpwwwjarchivecommedia20080723_j_02jpg',
#  'topically',
#  'milestones',
#  'coordinates',
#  'target_blanksinkholesa',
#  'hrefhttpwwwjarchivecommedia20011002_j_28wmvherea',
#  'dewinter',
#  'carbonaceous',
#  'glucks',
#  'realfyre',
#  'lateterm',
#  'pernission',
#  'torpor',
#  'massachusettsa',
#  'miscellaneous',
#  'target_blankuseda',
#  'firearm',
#  'hrefhttpwwwjarchivecommedia20050215_dj_10jpg',
#  'fseries',
#  'species',
#  '800foot',
#  'pridotite',
#  'formulas',
#  '20lire',
#  'scored',
#  'kenyons',
#  'twicedivorced',
#  'courtordered',
#  'hrefhttpwwwjarchivecommedia20050629_j_10wmviwhen',
#  'hallam',
#  'sogrape',
#  'embark',
#  'birdbrained',
#  'resale',
#  'electroantennogram',
#  'antimony',
#  'leighanne',
#  'perfumista',
#  'darmstadt',
#  'boycotting',
#  'hrefhttpwwwjarchivecommedia20050208_fjjpg',
#  'presently',
#  'slowfalling',
#  'balenciaga',
#  'looser',
#  'anacondas',
#  'mannera',
#  'hrefhttpwwwjarchivecommedia20090917_dj_07jpg',
#  'iacomus',
#  'negotiators',
#  'target_blankferocitya',
#  'penetrate',
#  'muppeteer',
#  'tintinnabulating',
#  'yatsen',
#  'indira',
#  'palins',
#  'facilitya',
#  'landspeed',
#  'inappropriate',
#  'bighorn',
#  'evocatively',
#  'hrefhttpwwwjarchivecommedia20060713_dj_26jpg',
#  'prelature',
#  'salarium',
#  'hrefhttpwwwjarchivecommedia20071010_dj_30jpg',
#  'collard',
#  'hrefhttpwwwjarchivecommedia20090918_j_18ajpg',
#  'rhodamine',
#  'hrefhttpwwwjarchivecommedia20110628_dj_25jpg',
#  'hrefhttpwwwjarchivecommedia20091214_j_07jpg',
#  'gnarled',
#  'luccilong',
#  'dahalo',
#  'deepening',
#  'target_blankceremonya',
#  'hrefhttpwwwjarchivecommedia20080325_j_03jpg',
#  'electrify',
#  'sunherald',
#  'hrefhttpwwwjarchivecommedia20091208_dj_18jpg',
#  'fruita',
#  'hrefhttpwwwjarchivecommedia20090306_dj_15jpg',
#  'zonealarm',
#  'hrefhttpwwwjarchivecommedia20111223_dj_20jpg',
#  'zachariah',
#  'bronchodilator',
#  'shopkeepers',
#  'adverbial',
#  'tapestries',
#  'ripping',
#  'kordofanian',
#  'schwedagon',
#  '15year',
#  'hrefhttpwwwjarchivecommedia20081208_dj_28jpg',
#  'refugees',
#  'jamaica',
#  'hrefhttpwwwjarchivecommedia20020902_dj_07ajpg',
#  'moffat',
#  'hrefhttpwwwjarchivecommedia20020508_j_05jpg',
#  'hrefhttpwwwjarchivecommedia20070212_dj_09jpg',
#  'hrefhttpwwwjarchivecommedia20071224_j_24jpg',
#  'tributaries',
#  'durability',
#  'django',
#  'abolish',
#  'mcdowall',
#  'dilapidated',
#  'advises',
#  '1976present',
#  'dipped',
#  'hrefhttpwwwjarchivecommedia20061109_j_15ajpg',
#  'kidnaps',
#  'fevrier',
#  'hrefhttpwwwjarchivecommedia20061011_j_10jpg',
#  'bunnies',
#  'hrefhttpwwwjarchivecommedia20111121_j_16wmvsarah',
#  'serifs',
#  'protopopovs',
#  'hrefhttpwwwjarchivecommedia20070727_dj_13jpg',
#  'hrefhttpwwwjarchivecommedia20060324_j_04mp3ill',
#  'hrefhttpwwwjarchivecommedia20050406_dj_18mp3in',
#  'captain',
#  'abounding',
#  'target_blankfriezea',
#  'etatsunis',
#  'received',
#  'mattresses',
#  'palmers',
#  'guyanese',
#  'subzones',
#  'coppers',
#  'chalchihuitlicue',
#  'derailleur',
#  'hrefhttpwwwjarchivecommedia20011025_dj_14jpg',
#  'beaktotail',
#  'alerts',
#  'miercoles',
#  'qiblahs',
#  'baskervilles',
#  'britishamerican',
#  'embroidery',
#  'allemagne',
#  'baumgarner',
#  'triplebypass',
#  'target_blankthea',
#  'over100yearold',
#  'cruzeiro',
#  'cruiser',
#  'hrefhttpwwwjarchivecommedia20060421_j_04jpg',
#  'peoplepowered',
#  'autumns',
#  'arjumand',
#  'carrick',
#  'rezazadeh',
#  'dejected',
#  'cryptologic',
#  'hrefhttpwwwjarchivecommedia20080327_dj_30ajpg',
#  'ribbittickler',
#  'fullfil',
#  'hrefhttpwwwjarchivecommedia20080611_j_27jpg',
#  'target_blanka10',
#  '6headed',
#  'anywaya',
#  'periodic',
#  'bournes',
#  'transducer',
#  'hrefhttpwwwjarchivecommedia20090625_dj_24jpg',
#  'contemptuous',
#  'neujahrstag',
#  'feeder',
#  'amourous',
#  'opositive',
#  'hrefhttpwwwjarchivecommedia20060712_j_11mp3i',
#  'marmosets',
#  'unspoken',
#  'nominations',
#  'hominidae',
#  'cotelette',
#  'friedrichsruh',
#  'deryks',
#  'hrefhttpwwwjarchivecommedia20051104_dj_25ajpg',
#  'superintendent',
#  'loathed',
#  'hrefhttpwwwjarchivecommedia20100122_dj_28jpg',
#  'kinderhook',
#  '198789',
#  'tactful',
#  'stinka',
#  'chaser',
#  'allseasonable',
#  'ciciri',
#  'ecstasy',
#  'yuppieville',
#  'timewise',
#  'professional',
#  'academie',
#  'perignon',
#  'inquiry',
#  'kyrgyzstan',
#  'nearboiling',
#  'hypothis',
#  'shaded',
#  'couliers',
#  'preprogrammed',
#  'hrefhttpwwwjarchivecommedia19970905_fjjpg',
#  'postmark',
#  'hrefhttpwwwjarchivecommedia20061106_j_30jpg',
#  'turtlesa',
#  'insemination',
#  'sleeveless',
#  'proposes',
#  'discourage',
#  'peruggia',
#  'boating',
#  'seborrheic',
#  'thompsons',
#  'africanborn',
#  'revolutionaryera',
#  'marrone',
#  'avenos',
#  'remodel',
#  'solidly',
#  'stemberg',
#  'monarchial',
#  'claque',
#  'ysleta',
#  'methodist',
#  'haliotis',
#  'bitterns',
#  '15sept',
#  'bookie',
#  'huerta',
#  'torino',
#  'tenaciously',
#  'painrelieving',
#  'middlesex',
#  'boards',
#  'wilbur',
#  'hrefhttpwwwjarchivecommedia20100205_j_26wmvjimmy',
#  'sailcloth',
#  'anybody',
#  'pacoima',
#  'persecutest',
#  'xstatic',
#  'wthirst',
#  'hrefhttpwwwjarchivecommedia20060201_dj_06mp3alors',
#  'breastfed',
#  'operaman',
#  'saltcellars',
#  'eruptions',
#  'unseated',
#  'minuend',
#  'hrefhttpwwwjarchivecommedia20061115_j_21jpg',
#  'gamalielese',
#  'allegra',
#  'schweinhund',
#  'apparela',
#  'godson',
#  'ascorbic',
#  'cocoons',
#  'ingoal',
#  'iliamna',
#  'pantsjacket',
#  'entranced',
#  'whitefish',
#  'pyramidal',
#  'hrefhttpwwwjarchivecommedia20020906_dj_21jpg',
#  'lalique',
#  'benchlike',
#  'choreographers',
#  'americansjust',
#  'heroes',
#  'hickoks',
#  'flightcapable',
#  'target_blankbooka',
#  'bluebird',
#  'ichthyological',
#  'basalt',
#  'viscera',
#  'trained',
#  'hrefhttpwwwjarchivecommedia20080123_dj_30wmvjimmy',
#  'hrefhttpwwwjarchivecommedia20100202_dj_18wmvthisa',
#  'target_blankmudheada',
#  'alwaysfrozen',
#  'teaspoon',
#  'barely',
#  'exgenerals',
#  'threat',
#  'multicolumn',
#  'intrusive',
#  'harford',
#  'zhivago',
#  'hrefhttpwwwjarchivecommedia20100923_dj_09jpg',
#  'lorikeets',
#  'hrefhttpwwwjarchivecommedia20110511_j_15jpg',
#  'robstown',
#  'profligate',
#  'londona',
#  'infected',
#  'abstaining',
#  'boogie',
#  'carves',
#  'calidarium',
#  'spiralshaped',
#  'serious',
#  'insecure',
#  'harpercollins',
#  'beckham',
#  'rematches',
#  'mercenaries',
#  'morgenthaler',
#  'marcian',
#  'semitough',
#  'maydecember',
#  'hangingfromtrees',
#  'hrefhttpwwwjarchivecommedia20110527_j_29jpg',
#  'sulawesi',
#  'hrefhttpwwwjarchivecommedia20080219_j_04ajpg',
#  'target_blankyellow',
#  '155yearold',
#  'trotted',
#  'stampeded',
#  'grantjimmy',
#  'congregationalist',
#  'argonauts',
#  'industrialstyle',
#  'resided',
#  'msnbcs',
#  'hrefhttpwwwjarchivecommedia20080926_dj_27jpg',
#  'profundo',
#  'transplantation',
#  'hrefhttpwwwjarchivecommedia20070219_j_04mp3thisa',
#  'overpigmented',
#  'acetic',
#  'paulets',
#  'adviser',
#  'hrefhttpwwwjarchivecommedia20071112_dj_04ajpg',
#  'hemophiliac',
#  'fingals',
#  'polysaccharides',
#  'hrefhttpwwwjarchivecommedia20070524_j_04jpg',
#  'doubloons',
#  'liberators',
#  'chewing',
#  'stumpers',
#  'ishikari',
#  'goldens',
#  'signals',
#  'readjust',
#  'grapevinea',
#  'hofsjokull',
#  'flagstaff',
#  'hrefhttpwwwjarchivecommedia20090210_j_29wmvvanna',
#  'cratchits',
#  'salammbo',
#  'unpasteurized',
#  'grader',
#  'legitimized',
#  'beefsteak',
#  'bogota',
#  'rodshaped',
#  'convention',
#  'saddam',
#  'hrefhttpwwwjarchivecommedia20110404_dj_21jpg',
#  'lithophone',
#  'hrefhttpwwwjarchivecommedia20050105_j_04jpg',
#  'constelations',
#  'fetches',
#  'saturated',
#  'becquerel',
#  'stiller',
#  'lossnot',
#  'reginald',
#  'retried',
#  'schleps',
#  'simile',
#  'behistun',
#  'impoverished',
#  'yankovic',
#  'hrefhttpwwwjarchivecommedia20091216_dj_03jpg',
#  'hrefhttpwwwjarchivecommedia20100713_j_25wmvsarah',
#  'atlases',
#  '1900giddyup',
#  'garbology',
#  'freeholdborn',
#  'shopping',
#  'jamaicanborn',
#  'splitter',
#  'hrefhttpwwwjarchivecommedia20050421_j_03jpg',
#  'hrefhttpwwwjarchivecommedia20100915_j_21jpg',
#  '195556',
#  'belloq',
#  'pleasantly',
#  'totaled',
#  'cynical',
#  'horsebit',
#  'maniac',
#  'civilzations',
#  'hrefhttpwwwjarchivecommedia20110204_dj_30wmvthisa',
#  'daydreamer',
#  'technothrillers',
#  'aptiva',
#  'gliniecki',
#  'slangier',
#  'mcclellans',
#  'hrefhttpwwwjarchivecommedia20060104_dj_30ajpg',
#  'festivals',
#  'diaperscom',
#  'rusesabagina',
#  'icteridae',
#  'for_applause',
#  'ridgeback',
#  'corrected',
#  'affixes',
#  'prizeit',
#  'folkie',
#  'bebida',
#  'hrefhttpwwwjarchivecommedia20050422_dj_04jpg',
#  'hannitys',
#  'shinkansen',
#  '19year',
#  'spavinaw',
#  'taiaut',
#  'outreach',
#  'hrefhttpwwwjarchivecommedia20051012_dj_27jpg',
#  'colliery',
#  'deeley',
#  'rethinks',
#  'marshy',
#  'gallophobia',
#  'petroleos',
#  'hrefhttpwwwjarchivecommedia20061017_dj_13jpg',
#  'universalist',
#  'commedia',
#  'dogood',
#  'ugandans',
#  'balaam',
#  'emphasize',
#  'hingham',
#  'paschs',
#  'annuity',
#  'flipflops',
#  'hennin',
#  'brunell',
#  'surname',
#  'massed',
#  'baptizer',
#  'heisenberg',
#  'unhusked',
#  'weskit',
#  'manufacturer',
#  'interchangeably',
#  'winnable',
#  'kalikow',
#  'hrefhttpwwwjarchivecommedia20070910_dj_29jpg',
#  'protosurrealist',
#  'rogers',
#  'finlandia',
#  'target_blankpaintinga',
#  'linear',
#  'jorsalfar',
#  'gasser',
#  'forefingers',
#  'husbandtobe',
#  'hrefhttpwwwjarchivecommedia20081222_j_26ajpg',
#  'craigslist',
#  'meanetca',
#  'curple',
#  'expensive',
#  'kschessinska',
#  'perzovhka',
#  'conifer',
#  'partway',
#  'colenterates',
#  'hitchcock',
#  'unconditionally',
#  'hrefhttpwwwjarchivecommedia20060419_j_21mp3herea',
#  'thracians',
#  'crimesolving',
#  'kinetix',
#  'lancaster',
#  'gristle',
#  'fabens',
#  'tented',
#  'judeochristian',
#  'halfalien',
#  'mothership',
#  'shipments',
#  'listener',
#  'afford',
#  'smithtommy',
#  '1to500dollar',
#  'monkees',
#  'docucomedy',
#  'onthenosea',
#  'hrefhttpwwwjarchivecommedia20100506_j_18wmvthesea',
#  'wellworn',
#  'graziano',
#  'planks',
#  'underlie',
#  'formosa',
#  'hrefhttpwwwjarchivecommedia20050920_j_02mp3its',
#  'mccaffrey',
#  'hrefhttpwwwjarchivecommedia20051021_dj_22jpg',
#  'recurrences',
#  'donation',
#  'tigerseye',
#  'spirant',
#  'everdangerous',
#  'practicing',
#  'afflict',
#  'glacial',
#  'robinson',
#  'ridgeway',
#  'carolines',
#  'ephrya',
#  'struggles',
#  'sovereignty',
#  'diddly',
#  'hrefhttpwwwjarchivecommedia20101109_j_21wmvthisa',
#  'mangrove',
#  'lundlazlo',
#  'hommes',
#  'spender',
#  'cowrite',
#  'amuses',
#  'contains',
#  'spanishlanguage',
#  'huffingtonpostcom',
#  'emperors',
#  'silkeborg',
#  'ovaltine',
#  'bodices',
#  'orshansky',
#  'fortwo',
#  'norworth',
#  'fissionable',
#  'hrefhttpwwwjarchivecommedia20010109_dj_19jpg',
#  'vanilli',
#  'hrefhttpwwwjarchivecommedia20060308_dj_03mp3schweizerische',
#  'melanesia',
#  'undersized',
#  'puffed',
#  'mapplethorpe',
#  'contemplate',
#  'hrefhttpwwwjarchivecommedia20070322_dj_23jpg',
#  'acapulco',
#  'heerlena',
#  'exrracted',
#  'casters',
#  'flickers',
#  'hrefhttpwwwjarchivecommedia20111208_j_08jpg',
#  'artesian',
#  'batgirls',
#  'environmentally',
#  'taschhorn',
#  '1000pound',
#  'steppe',
#  '2digit',
#  'chrysaor',
#  'hassan',
#  'hrefhttpwwwjarchivecommedia20050629_j_10bjpg',
#  'soldered',
#  'sobriquets',
#  'tasket',
#  'ascent',
#  '2000yearold',
#  'rakoczy',
#  'dragnets',
#  'helmsman',
#  'hrefhttpwwwjarchivecommedia20090608_j_13mp3why',
#  'midland',
#  '10inch',
#  'doctorows',
#  'courvoisier',
#  'hrefhttpwwwjarchivecommedia20041013_dj_19wmvherea',
#  'target_blankcolumna',
#  'annapurna',
#  'djproduced',
#  'cereal',
#  'camrys',
#  'cellular',
#  'target_blanklockboxa',
#  'kwongsang',
#  'lisztomania',
#  'slavers',
#  ...}

# %% [markdown]
# ## Findings:
#
# There is about an 87% overlap between the terms in new questions and the terms in old questions. This only looks at a small set of questions though - it doesn't look at phrases - and it only looks at single terms. This makes it relatively insignificant because were not looking at the entirety of the question; but, it does mean that it's worth looking more into the recycling of questions to see if we can discover any insight.

# %% [markdown]
# I'll now take a look at the values of the questions - maybe I can find something by comparing high and low value questions. I'll create a function to categorize questions into high (greater than 800) and low: 0 corresponds to low, 1 corresponds to high.

# %%
def values(row):
    value = 0
    if row["clean_value"] > 800:
        value = 1
    return value
        
df["high_value"] = df.apply(values, axis=1)
df["high_value"].value_counts(normalize=True)
# Out:
# 0    0.716855
# 1    0.283145
# Name: high_value, dtype: float64

# %% [markdown]
# With value categories, I can create a function to count up the low and high value questions. Afterwards, I will find the amount of times the terms - in the terms_used (unique words) set - are found within high or low value questions. We can then use this observed counts to find their expected counts to do a chi square test. A chi square test can possibly help me figure out which terms correspond to high value questions - which can maybe help me earn more money on the game.

# %%
def counts(term):
    low_count = 0
    high_count = 0
    for i, v in df.iterrows():
        if term in v["clean_question"].split(" "):
            if v["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return low_count, high_count   

observed_expected = []
comparison_terms = list(terms_used)[:5]
for term in comparison_terms:
    observed_expected.append(counts(term))
    
observed_expected
# Out:
# [(1, 0), (31, 6), (0, 1), (1, 0), (8, 11)]

# %% [markdown]
# Finding chi-square values and p-values for a small sample of terms.

# %%
from scipy.stats import chisquare


high_value_count = df[df["high_value"] == 1].shape[0]
low_value_count = df[df["high_value"] == 0].shape[0]

chi_squared = []
for tup in observed_expected:
    total = sum(tup)
    total_prop = total/len(df)
    high_val_rows = total_prop * high_value_count
    low_val_rows = total_prop * low_value_count
    
    observed = np.array([tup[0], tup[1]])
    expected = np.array([high_val_rows, low_val_rows])
    chi_squared.append(chisquare(observed, expected))

# %%
chi_squared
# Out:
# [Power_divergenceResult(statistic=2.5317638631109367, pvalue=0.11157543053393834),
#  Power_divergenceResult(statistic=56.08768670372833, pvalue=6.930983431963572e-14),
#  Power_divergenceResult(statistic=0.39498154412048414, pvalue=0.5296924445254796),
#  Power_divergenceResult(statistic=2.5317638631109367, pvalue=0.11157543053393834),
#  Power_divergenceResult(statistic=1.7802975830357144, pvalue=0.18211278920192042)]

# %% [markdown]
# ## Conclusion:
#
# None of the terms had a statistically significant difference in their usage between high value and low value rows. Also, the frequencies were all lower than 5, giving the chi-squared test not much statistical significance. It would be better to run this test with only terms that have higher frequencies, but I'll save that for a future project.
